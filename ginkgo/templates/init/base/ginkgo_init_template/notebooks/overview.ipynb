# %% [markdown]
# # Starter Overview
#
# This notebook is rendered by the default `ginkgo init` workflow.

# %%
import json
from pathlib import Path

summary = json.loads(Path(summary_path).read_text(encoding="utf-8"))  # noqa: F821
print(f"run_label={run_label}")  # noqa: F821
print(f"row_count={summary['row_count']}")
for row in summary["rows"]:
    print(f"- {row['item']}: {row['brief']}")
