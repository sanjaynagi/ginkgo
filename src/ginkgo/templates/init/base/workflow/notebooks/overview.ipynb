# %% [markdown]
# # Starter Overview
#
# This notebook is rendered by the default `ginkgo init` workflow.
#
# The cell below is tagged `parameters`. Ginkgo passes the notebook task's
# arguments to Papermill, which replaces that cell's contents at run time. The
# values written there are the defaults used when you open the notebook by hand;
# during a run the task signature in `workflow/modules/reporting.py` wins.

# %%
summary_path = "results/summary.json"
run_label = "Starter demo"

# %%
import json
from pathlib import Path

import pandas as pd

summary = json.loads(Path(summary_path).read_text(encoding="utf-8"))
print(f"run_label={run_label}")
print(f"row_count={summary['row_count']}")

rows = pd.DataFrame(summary["rows"])
rows
